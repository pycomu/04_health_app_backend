# %% [markdown]
# https://medium.datadriveninvestor.com/flask-on-colab-825d2099d9d8 how to run FastAPI on G-Colab.

# %%
# !pip install fastapi nest-asyncio pyngrok uvicorn
# Out:
# ...
#      |████████████████████████████████| 51 kB 590 kB/s
# ...
#      |████████████████████████████████| 745 kB 39.0 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 61 kB 275 kB/s
# ...
#      |████████████████████████████████| 10.1 MB 48.5 MB/s
# ...
#      |████████████████████████████████| 78 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.2 MB/s
# ...
#   Created wheel for pyngrok: filename=pyngrok-5.1.0-py3-none-any.whl size=19006 sha256=eb48d38b4dc3c668d323763b6fe901411d303f647b46225753df1d196ddd8f83
#   Stored in directory: /root/.cache/pip/wheels/bf/e6/af/ccf6598ecefecd44104069371795cb9b3afbcd16987f6ccfb3
# Successfully built pyngrok
# ...

# %%
from fastapi import FastAPI
import nest_asyncio
from pyngrok import ngrok
import uvicorn

app = FastAPI()

@app.get('/index')
async def home():
  return "Hello World"

ngrok_tunnel = ngrok.connect(8000)
print('Public URL:', ngrok_tunnel.public_url)
nest_asyncio.apply()
uvicorn.run(app, port=8000)
# Out:
# INFO:     Started server process [66]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# Public URL: http://f734-34-86-179-165.ngrok.io
# INFO:     2001:a61:3b77:2b01:2dfa:abaf:5bdb:3779:0 - "GET / HTTP/1.1" 404 Not Found
# INFO:     2001:a61:3b77:2b01:2dfa:abaf:5bdb:3779:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     2001:a61:3b77:2b01:2dfa:abaf:5bdb:3779:0 - "GET /index HTTP/1.1" 200 OK
# INFO:     2001:a61:3b77:2b01:2dfa:abaf:5bdb:3779:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     2001:a61:3b77:2b01:2dfa:abaf:5bdb:3779:0 - "GET /docs HTTP/1.1" 200 OK
# INFO:     2001:a61:3b77:2b01:2dfa:abaf:5bdb:3779:0 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [66]

# %% [markdown]
# Our FastAPI server is up and running and let’s type {Public_URL}/index on the  browser to reach out to our endpoint as we created one route only i.e. /index.
